# %%
import os
import dotenv

# Load the environment variables from .venv file
dotenv.load_dotenv('.env')

#GEMINI_API_KEY = 'ok'

# Get the value of CHATGPT_API_KEY from the environment
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

#print(GEMINI_API_KEY)

# %%
import glob
import os

ESBM = {}


# Define the path pattern to find .txt files in the data folder
path_pattern = 'data/dbpedia/*.txt'

# Use glob to get a list of all .txt files in the data folder
file_list = glob.glob(path_pattern)

# Loop through each file found
for file_path in file_list:
    print(f'Processing file: {file_path}')
    
    # Generate an output filename based on the input filename
    base_name = os.path.basename(file_path)
    output_file_name = f'output_{base_name}'
    
    clean_base_name = base_name.split('.txt')[0]
    print(clean_base_name)
    if clean_base_name not in ESBM:
        ESBM[clean_base_name] = {}

    with open(file_path, 'r') as file:

        for line in file:
            # Split the line on tabs to isolate the URL
            parts = line.split('\t')

            if len(parts) > 1:  # Check if there are at least two parts after splitting
                url = parts[1].strip()  # Get the URL part and remove any extra spaces
                
                # Extract the last part of the URL after the last '/'
                last_part = url.split('/')[-1]
                
                # Remove trailing comma if it exists
                if last_part.endswith(','):
                    last_part = last_part[:-1]
                
                # Replace underscores with spaces if necessary
                # Check if there are underscores and then replace them with spaces
                if '_' in last_part:
                    last_part = last_part.replace('_', ' ')

                # Check if the base_name is already in the dictionary
                
                
                ESBM[clean_base_name][parts[0]] = last_part
                #ids.append(parts[0])
                #data.append(last_part)

        #ESBM[base_name] = data

        #data = []

print(ESBM)
# Out:
# Processing file: data/dbpedia/ESBM_benchmark_v1.0.txt
# ESBM_benchmark_v1.0
# Processing file: data/dbpedia/ESBM_benchmark_v1.2.txt
# ESBM_benchmark_v1.2
# {'ESBM_benchmark_v1.0': {'1': '3WAY FM', '2': 'Adrian Griffin', '3': 'Andrew Kippis', '4': 'Anthony Beaumont-Dark', '5': 'Dallas Keuchel', '6': 'E. K. Mawlong', '7': 'Finn Schiander', '8': 'Hagar Wilde', '9': 'Ludwigsburg University', '10': 'Roderick Carr', '11': '2009–10 Swiss Cup', '12': '2011 Kor Royal Cup', '13': '2012 League of Ireland Cup Final', '14': '2011 Sparta Prague Open', '15': '2012–13 UEFA Champions League', '16': 'Battle of Bregalnica', '17': 'Battle of Rottofreddo', '18': 'Burgery ambush', '19': 'Massacre on 34th Street', '20': "Triathlon at the 2000 Summer Olympics – Men's", '21': 'Akalwadi', '22': 'Chitita', '23': 'Kuleh Bayan', '24': 'Phong Thạnh Tây', '25': 'Reamer Barn', '26': 'Richmond–Petersburg Turnpike', '27': 'Uelsby', '28': 'Wehlaberg', '29': 'Wernshausen', '30': 'Yayoidai Station', '31': 'African grey hornbill', '32': 'Bornean mountain ground squirrel', '33': 'Eastern Sumatran rhinoceros', '34': 'Enallagma truncatum', '35': 'Lepiota helveola', '36': 'Lygodium microphyllum', '37': 'Ovophis', '38': 'Rubus arizonensis', '39': 'Siamese mud carp', '40': 'Trachelipus dimorphus', '41': 'Foppt den Dämon!', '42': 'Hey Boy (Teddybears song)', '43': 'King of the Mountain (film)', '44': 'Our Leading Citizen (1939 film)', '45': 'Simon (2004 film)', '46': 'Sketchy EP 1', '47': 'Sky (Faye Wong album)', '48': 'Sting Me', '49': 'The Crowd Snores', '50': 'Touch of Death (1961 film)', '51': 'Ashot I of Iberia', '52': 'Cindy Mackey', '53': 'Edmund Smith Conklin', '54': 'Fabrice Gautrat', '55': 'Hiroshi Mori (writer)', '56': 'Momchil Tsvetanov', '57': 'Najmadin Shukr Rauf', '58': 'Storme Warren', '59': 'Svyatoslav Tanasov', '60': 'William Anthony Hughes', '61': '1960 Glover Trophy', '62': '1967 Italian Grand Prix', '63': '2008 Copa América – FIFA Futsal', '64': '2008 Copa del Rey Final', '65': '2010 Belgian Super Cup', '66': '2013 Slovak Cup Final', '67': 'Battle of Calicut (1502)', '68': 'Battle of Cepeda (1820)', '69': 'Battle on the Elster', '70': 'Operation Hump', '71': 'Darreh Dang', '72': 'Jalalia, Khyber Pakhtunkhwa', '73': 'Kings Ripton', '74': 'Kotumachagi', '75': 'Muławki', '76': 'Pinnacle Mountain (South Carolina)', '77': 'Saint-Raphaël, Var', '78': 'Sauxillanges', '79': 'Stara Bučka', '80': 'Zarudcze', '81': 'Amphisbaena ridleyi', '82': 'Balanites', '83': 'Bryotropha plantariella', '84': 'Hilarographa excellens', '85': 'Inverted repeat-lacking clade', '86': 'Melaleuca sheathiana', '87': 'Pseudanos trimaculatus', '88': 'Stemonoporus laevifolius', '89': 'Thaia saprophytica', '90': 'Trichoscypha cavalliensis', '91': '392 (album)', '92': 'Drama City', '93': 'If (Glasvegas song)', '94': 'Intensive Care Medicine (journal)', '95': "It's Still Rock and Roll to Me", '96': 'Politiken', '97': 'Rebel Love Song', '98': 'Terrorist Threats', '99': 'Time (Dave Clark album)', '100': 'Wide Awake Drunk'}, 'ESBM_benchmark_v1.2': {'1': '3WAY FM', '2': 'Adrian Griffin', '3': 'Andrew Kippis', '4': 'Anthony Beaumont-Dark', '5': 'Dallas Keuchel', '6': 'E. K. Mawlong', '7': 'Finn Schiander', '8': 'Hagar Wilde', '9': 'Ludwigsburg University', '10': 'Roderick Carr', '11': '2009–10 Swiss Cup', '12': '2011 Kor Royal Cup', '13': '2012 League of Ireland Cup Final', '14': '2011 Sparta Prague Open', '15': '2012–13 UEFA Champions League', '16': 'Battle of Bregalnica', '17': 'Battle of Rottofreddo', '18': 'Burgery ambush', '19': 'Massacre on 34th Street', '20': "Triathlon at the 2000 Summer Olympics – Men's", '21': 'Akalwadi', '22': 'Chitita', '23': 'Kuleh Bayan', '24': 'Phong Thạnh Tây', '25': 'Reamer Barn', '26': 'Richmond–Petersburg Turnpike', '27': 'Uelsby', '28': 'Wehlaberg', '29': 'Wernshausen', '30': 'Yayoidai Station', '31': 'African grey hornbill', '32': 'Bornean mountain ground squirrel', '33': 'Eastern Sumatran rhinoceros', '34': 'Enallagma truncatum', '35': 'Lepiota helveola', '36': 'Lygodium microphyllum', '37': 'Ovophis', '38': 'Rubus arizonensis', '39': 'Siamese mud carp', '40': 'Trachelipus dimorphus', '41': 'Foppt den Dämon!' ...

# %%
import math
import numpy as np

import glob
import os
import json  # Import JSON to write output files

import google.generativeai as genai

# Set your API key
genai.configure(api_key=GEMINI_API_KEY)

# Assuming ESBM is a predefined dictionary
for key, value in ESBM.items():
    path_pattern = f'data/dbpedia/{key}'
    folder_list = glob.glob(path_pattern)
    
    json_output_list = []  # List to hold output dictionaries

    # Loop through each file found
    for file_path in folder_list:
        print(f'Processing folder: {file_path}')
        
        # Generate an output filename based on the folder name
        base_name = os.path.basename(file_path)

        for key2, value2 in value.items():
            file_list = glob.glob(f'{file_path}/{key2}/*top*.nt')

            for nt_file in file_list:
                print(f'Processing file: {nt_file}')
                with open(nt_file, 'r') as file:
                    rdf_content = file.read()
                
                try:
                    # Define the query
                    query = f"I will give you text - triples and you will respond strictly with coherent text without using your knowledge but only the triples. Triples are: {rdf_content}"

                    # Make the request
                    model = genai.GenerativeModel("gemini-1.5-flash")
                    response = model.generate_content(query)
                    #print(response.text)

                    # Create dictionary for JSON output
                    output_dict = {
                        "id": str(key2),
                        "filename": nt_file,
                        "Title": value[key2],  # Assuming the folder name as title
                        "Answer": response.text,
                        "sparql_query": rdf_content  # Assuming this field is empty for now
                    }
                    json_output_list.append(output_dict)
                    

                except Exception as e:
                    print(f"Error processing file {nt_file}: {e}")
                    break

    # Write the output list to a JSON file for each folder
    json_output_path = os.path.join(file_path, f'{base_name}_gemini_output_top.json')
    with open(json_output_path, 'w') as json_file:
        json.dump(json_output_list, json_file, indent=4)

    print(f'JSON output written to: {json_output_path}')
# Out:
# Processing folder: data/dbpedia/ESBM_benchmark_v1.0
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/1/1_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/1/1_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/2/2_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/2/2_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/3/3_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/3/3_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/4/4_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/4/4_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/5/5_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/5/5_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/6/6_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/6/6_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/7/7_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/7/7_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/8/8_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/8/8_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/9/9_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/9/9_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/10/10_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/10/10_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/11/11_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/11/11_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/12/12_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/12/12_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/13/13_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/13/13_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/14/14_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/14/14_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/15/15_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/15/15_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/16/16_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/16/16_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/17/17_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/17/17_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/18/18_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/18/18_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/19/19_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/19/19_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/20/20_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/20/20_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/21/21_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/21/21_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/22/22_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/22/22_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/23/23_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/23/23_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/24/24_top5.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0/24/24_top10.nt
# Processing file: data/dbpedia/ESBM_benchmark_v1.0